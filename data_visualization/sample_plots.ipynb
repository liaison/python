# %% [markdown]
# ## Abstract
#
# In this notebook, we show some examples on how to use the python libraries notably matplotlib and seaborn to plot data from DataFrame.
#
# Some references:
#
# - [https://python-graph-gallery.com/scatter-plot/](https://python-graph-gallery.com/scatter-plot/)
#
# - [https://python-graph-gallery.com/82-marginal-plot-with-seaborn/](https://python-graph-gallery.com/82-marginal-plot-with-seaborn/)

# %%
import pandas as pd
import numpy as np

from sklearn import datasets

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15,6
rcParams['figure.dpi'] = 300
rcParams['savefig.dpi'] = 300

# %%
iris = datasets.load_iris()

df_iris = pd.DataFrame(iris.data, columns=iris.feature_names)
df_iris['target'] = iris['target']

df_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
_ = df_iris.hist(figsize=(15, 20))

# %%
_ = sns.countplot(x='sepal length (cm)', data=df_iris, hue='target')

# %%
sns.pairplot(df_iris, kind='scatter', hue='target')

# %%
df = sns.load_dataset('iris')

sns.pairplot(df, kind="scatter", hue="species", markers=["o", "s", "D"], palette="Set2")
plt.show()

# %%
# right: you can give other arguments with plot_kws.
sns.pairplot(df, kind="scatter", hue="species", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
plt.show()

# %%
#sns.set()

#sns.pairplot(df_iris, hue='target')
#_ = plt.suptitle('Scatter Plot for Iris data')

# %%
sns.set(style="whitegrid", palette="muted")

sns.pairplot(df_iris, diag_kind='kde')
